# %% [markdown]
# # GP12 GeoPandas EXERCISE FOUR
# ___

# %%
# Import libraries: Geopandas, Pandas, Matplotlip.pyplot, Folium and Plotly Express 
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
import folium
import plotly_express as px

# %% [markdown]
# ## 1. Load Spatial data
# * Load the file: localdata/incidentsClean.shp
# * Display the first 3 rows of the data.

# %%
# Out:
#    objectid  dc_dist psa        dispatch_d  dispatch_1 dispatch_t  hour_  \
# 0       129        9   2  25/03/2020 18:32  25/03/2020   18:32:00     18
# 1        41       77   A  08/03/2020 19:08  08/03/2020   19:08:00     19
# 2        42       77   A  15/03/2020 18:41  15/03/2020   18:41:00     18
#
#          dc_key                   location_b  ucr_genera          text_gener  \
# 0  2.020090e+11  1400 BLOCK SPRING GARDEN ST         600  Theft from Vehicle
# 1  2.020770e+11              0 BLOCK PIA WAY         600              Thefts
# 2  2.020770e+11              0 BLOCK PIA WAY         600              Thefts
#
#      point_x    point_y        lat        lng                    geometry
# 0 -75.161446  39.962334  39.962334 -75.161446  POINT (-75.16145 39.96233)
# 1 -75.230706  39.883881  39.883881 -75.230706  POINT (-75.23071 39.88388)
# 2 -75.230706  39.883881  39.883881 -75.230706  POINT (-75.23071 39.88388)

# %% [markdown]
# ___
# ## 1. Folium Map
# * Create a Folium basemap with the location of Philadelphia and default zoom at 11.

# %%
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# * Convert the basemap to cartodbpositron.

# %%
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# * Add the incidents Geodataframe to a Folium map to visualise the data points via the method: folium.GeoJson
# * Limit the same range to 1000 via the method: .sample(1000)

# %%
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ___
# ## 2. Folium Cluster Map
# * Create a cluster point map:
#     * Execute: **from folium.plugins import FastMarkerCluster**
#     * Pass in the FastMarkerCluster by using list(zip(i.geometry.y.values, i.geometry.x.values))
#     * Export and save the map as a HTML file.

# %% [markdown]
# ___
# ## 3. Plotly Express - Scatter Mapbox
# * Create a scatter_mapbox map via plotly Express with mapbox_style="open-street-map" and zoom=9.

# %% [markdown]
# ___
