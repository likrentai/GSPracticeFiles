# %% [markdown]
# # GP03 GeoPandas EXERCISE ONE
# ___

# %%
# Import libraries: Geopandas, Pandas and Matplotlip.pyplot
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Load Spatial data
# * Load the file: localdata/Philadelphia/Neighborhoods_Philadelphia.shp
# * Display the first 5 rows of the data

# %%
# Out:
#             NAME       LISTNAME        MAPNAME    Shape_Leng    Shape_Area  \
# 0     BRIDESBURG     Bridesburg     Bridesburg  27814.546521  4.458626e+07
# 1      BUSTLETON      Bustleton      Bustleton  48868.458365  1.140504e+08
# 2     CEDARBROOK     Cedarbrook     Cedarbrook  20021.415802  2.487174e+07
# 3  CHESTNUT_HILL  Chestnut Hill  Chestnut Hill  56394.297195  7.966498e+07
# 4     EAST_FALLS     East Falls     East Falls  27400.776417  4.057689e+07
#
#                                             geometry
# 0  POLYGON ((2719789.837 256235.538, 2719814.855 ...
# 1  POLYGON ((2733378.171 289259.945, 2732818.985 ...
# 2  POLYGON ((2685267.950 279747.336, 2685272.265 ...
# 3  POLYGON ((2678490.151 284400.400, 2678518.732 ...
# 4  POLYGON ((2686769.727 263625.367, 2686921.108 ...

# %% [markdown]
# * Plot the data of figure size = (12,8) with geopandas .plot() method

# %% [markdown]
# ___
# ## 2. Load CSV + GeoDataFrame Conversion
# * Load the CSV file: incidents.csv
# * Display the first 10 rows of the data

# %%
# Out:
#    objectid  dc_dist psa dispatch_date_time dispatch_date dispatch_time  \
# 0       129        9   2   25/03/2020 18:32    25/03/2020      18:32:00
# 1        41       77   A   08/03/2020 19:08    08/03/2020      19:08:00
# 2        42       77   A   15/03/2020 18:41    15/03/2020      18:41:00
# 3        43       77   A   18/03/2020 08:17    18/03/2020      08:17:00
# 4        44       77   A   03/04/2020 15:32    03/04/2020      15:32:33
# 5        47       77   A   11/02/2020 09:39    11/02/2020      09:39:00
# 6        48       77   A   24/02/2020 13:28    24/02/2020      13:28:00
# 7        49       77   A   27/02/2020 11:40    27/02/2020      11:40:00
# 8        50       77   A   05/03/2020 16:14    05/03/2020      16:14:00
# 9        51       77   A   06/03/2020 15:15    06/03/2020      15:15:00
#
#    hour_        dc_key               location_block  ucr_general  \
# 0     18  2.020090e+11  1400 BLOCK SPRING GARDEN ST          600
# ...

# %% [markdown]
# ### GeoDataframe Conversion
# * Find the column names for the coordinates (latitude and longitude columns).
# * Use gpd.GeoDataFrame() to pass in the identified columns with **.points_from_xy()** and **crs="EPSG:4326"**.
# * Display the first 3 rows of the data
# * Note: The conversion creates a geometry column in the dataset.

# %%
# Out:
#    objectid  dc_dist psa dispatch_date_time dispatch_date dispatch_time  \
# 0       129        9   2   25/03/2020 18:32    25/03/2020      18:32:00
# 1        41       77   A   08/03/2020 19:08    08/03/2020      19:08:00
# 2        42       77   A   15/03/2020 18:41    15/03/2020      18:41:00
#
#    hour_        dc_key               location_block  ucr_general  \
# 0     18  2.020090e+11  1400 BLOCK SPRING GARDEN ST          600
# 1     19  2.020770e+11              0 BLOCK PIA WAY          600
# 2     18  2.020770e+11              0 BLOCK PIA WAY          600
#
#     text_general_code    point_x    point_y        lat        lng  \
# 0  Theft from Vehicle -75.161446  39.962334  39.962334 -75.161446
# 1              Thefts -75.230706  39.883881  39.883881 -75.230706
# 2              Thefts -75.230706  39.883881  39.883881 -75.230706
#
#                      geometry
# 0  POINT (-75.16145 39.96233)
# 1  POINT (-75.23071 39.88388)
# 2  POINT (-75.23071 39.88388)

# %% [markdown]
# * Plot the GeoDataFrame with the .plot() method

# %%
# Out:
# <Axes: >

# %% [markdown]
# * The plot above shows outlier data points. These can be removed by using the condition **['lat']>38** for the latitude column.
# * Plot the clean up data with the figure size of (12,8) and the markersize of 0.2

# %% [markdown]
# * Save and export the cleaned data to the data folder under the name incidentsClean.shp.

# %% [markdown]
# ___
# ## 3. Projections
# * Check the coordinate reference system of the first GeoDataframe to find out the EPSG code and the measurement units.

# %% [markdown]
# * Check the coordinate reference system of the converted Geodataframe.

# %% [markdown]
# * The above two datasets have different CRS. Now set the CRS of the 2nd dataset ('incidents.csv') to the CRS of the 1st dataset ('Neighborhoods_Philadelphia.shp') via the .to_crs() method.
# * Check the new crs.

# %% [markdown]
# ___

# %% [markdown]
# ## 4. Overlay
# * Check the CRS of the 1st dataset ('Neighborhoods_Philadelphia.shp')

# %% [markdown]
# * Check the CRS of the cleaned 2nd dataset (from the above section 2 after the condition ['lat]>38)

# %% [markdown]
# * Notice that these two datasets have different CRS. Now change one of the above so that both CRS are the same format.

# %% [markdown]
# * Overlay the plots from the above two datasets to produce the image shown below:

# %%
# Out:
# <Axes: >

# %% [markdown]
# ___
